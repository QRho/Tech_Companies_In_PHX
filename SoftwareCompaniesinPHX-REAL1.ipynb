# %%
from splinter import Browser
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import pandas as pd
import requests
import os

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = 'https://gregslist.com/phoenix'
browser.visit(url)

#res=requests.get('https://gregslist.com/phoenix/')
#for num in range(2,8):
#res = requests.get(f'https://gregslist.com/phoenix/search?filtered=true{num}').text
#print(res)

# %%
html = browser.html
soup = BeautifulSoup(html, 'lxml')
#companies = soup.find_all('div', class_='list_text')

# %%
# companies = soup.find_all('section', id='company-list')
# print(companies)

company_listings=soup.find_all('div',class_='company-listing')
#website_listings=soup.find_all('a')['href']
print(company_listings[0])
#print(website_listings[10])
# Out:
# <div class="company-listing">
# <div class="row align-items-center">
# <div class="col-md-3 company-logo-column">
# <a href="http://www.1stproviderschoice.com/" target="_blank" title="View Website">1st Providers Choice</a>
# </div>
# <div class="col-md-7 company-details-column">
# ...

# %%
software=[]

for company in company_listings:
    
    
    title=company.find('a').text.strip()
    website = company.find('a')['href']
    #bins=company.find('span',class_='detail')
    detail=company.find('span',class_='detail')
    alldetails=company.find_all(rel='tag')
    #location=company.find('span').text.strip()
    
    
    
    if detail:
        detail=detail.text.strip()
    else:
        detail = 'None'
    

    software.append({
        'title':title,
        'detail':detail,
        'website':website,
        #'alldetails':alldetails,
        #'bins':bins,
       # 'location':location,
        #'employees':employees,
        #'businesstype':businesstype,
        
        })
    
# print(software)
    #print(detail)
    #print(title)
software_df=pd.DataFrame(software)
#print(software)

#software_df.to_csv(r'\Users\Radox Babe\Desktop\Software1.csv', index = False)

# %%
# Loop through returned results
# Error handling
url = 'https://gregslist.com/phoenix'
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'lxml')

company_listings=soup.find('div',class_='company-listing').text.strip()

company_listings
# Out:
# '1st Providers Choice\n\n\nElectronic medical records and practice management softwareJason Keele - CEOChandler, 11-50 employees, founded in 1989, Self-fundedB2B SaaS, Practice Management, Healthcare, Local HQ'

# %%
url = 'https://gregslist.com/phoenix'
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'lxml')

company_listings101=soup.find_all('div',class_='company-listing')


alldetail=[]
    
for company in company_listings101:   
    
    
    alldetails=company.find_all(rel='tag')
    
    
    #for a in soup.find_all('a', {'id':'phone-lead', 'rel': True}):
     #print(a['rel'])

    
    alldetail.append(alldetails)
   # alldetail.append ({
         #'alldetail':alldetails
    
    
#software_df1  

#software_df1=pd.DataFrame(alldetail)   
         
#newsoftware_df1=software_df1.rename(columns = {"Location": "0", 
                   #  "Employees":"1","Funding":"2", 
                   # "IndustryType":"3","Industry":"4","CompanyTYPE":"5","Headquarters":"6","Extra":"7"})       
    
    #(columns = {"0": "Location", 
                     #"1":"Employees","2":"Funding", 
                     #"3":"IndustryTYPE","4":"Industry","5":"CompanyTYPE","6":"Headquarters","7":"Extra"}) 
    

#software_df1.to_excel("output.xlsx",encoding="utf-8",
             #sheet_name='Sheet_name_1') 


#software_df1['0'] = software_df1['0'].str.get(0)  

#type(alldetail)   
    
#software_df1=pd.DataFrame(alldetail)
#software_df1

# software_df1.dtypes()



#software_df1['0'] = software_df1['0'].str[0]
#software_df1

# %%
software_df1
# Out:
#                0            1                        2           3  \
# 0     [Chandler]      [11-50]            [Self-funded]  [B2B SaaS]
# 1      [Phoenix]      [11-50]            [Self-funded]  [B2B SaaS]
# 2   [Scottsdale]  [1001-5000]              [VC-funded]  [B2B SaaS]
# 3   [Scottsdale]      [11-50]            [Self-funded]  [B2B SaaS]
# 4   [Scottsdale]     [51-200]              [VC-funded]  [B2B SaaS]
# ..           ...          ...                      ...         ...
# 86     [Gilbert]       [1-10]              [VC-funded]  [B2B SaaS]
# 87    [Chandler]     [51-200]  [Angel or Seed Funding]  [B2B SaaS]
# 88      [Tucson]       [1-10]            [Self-funded]  [B2B SaaS]
# 89          None         None                     None        None
# 90  [Scottsdale]       [1-10]            [Self-funded]  [B2B SaaS]
#
#                                  4                                          5  \
# 0            [Practice Management]                               [Healthcare]
# ...

# %% [markdown]
# software_df1[0][0]
#
#
#
#
# #Alldetail=company_listings.find('span',class_='detail').text.strip()
